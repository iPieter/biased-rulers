# %% [markdown]
# correlation of results

# %%
import json
import ast
import pandas as pd

a_file = open("Seat_SWP_templates_Language_models.json", "r")
seat_SWP_templates = a_file.read()
seat_SWP_templates = json.loads(seat_SWP_templates)

# %%
correlation_df = pd.DataFrame(seat_SWP_templates)
correlation_df
# Out:
#       temp1     temp2     temp3     temp4     temp5     temp6     temp7  \
# 0  0.697310  0.638042  0.526831  0.657153  0.769780  0.699615  0.426369
# 1  0.716191  0.761539  0.638168  0.538252  0.718469  0.855524  0.364053
# 2  0.726259  0.482323  0.438272  0.367341  0.589767  0.557613  0.645076
# 3  0.575352  0.679615  0.624736  0.692639  0.744659  0.745710  0.635425
# 4  0.588374  0.524936  0.429189  0.506633  0.382248  0.413249  0.418470
#
#       temp8     temp9    temp10    temp11
# 0  0.883557  0.732028  0.492450  0.548246
# 1  0.744915  0.270908  0.177106  1.058066
# 2  0.470532  0.635380  0.644608  0.811503
# 3  0.682944  0.611889  0.698984  0.712282
# 4  0.470509  0.643383  0.343785  0.231571

# %%
seat_SWP_templates
# Out:
# {'temp1': {'0': 0.6973097940653281,
#   '1': 0.7161906404882316,
#   '2': 0.7262587506258051,
#   '3': 0.5753516779477148,
#   '4': 0.5883735676816193},
#  'temp2': {'0': 0.6380417927901232,
#   '1': 0.76153891651494,
#   '2': 0.4823233219439905,
#   '3': 0.6796147934048773,
#   '4': 0.5249359284857726},
#  'temp3': {'0': 0.526830739334173,
#   '1': 0.6381677074285752,
#   '2': 0.4382724747196723,
#   '3': 0.6247362147488852,
#   '4': 0.4291889880253535},
#  'temp4': {'0': 0.6571533112974566,
#   '1': 0.5382523873979591,
#   '2': 0.36734113973550936,
#   '3': 0.6926390803026279,
#   '4': 0.506632763896542},
#  'temp5': {'0': 0.7697797690278761,
#   '1': 0.7184686780742054,
#   '2': 0.5897673638382551,
#   '3': 0.7446589271969147,
#   '4': 0.3822477115258905},
#  'temp6': {'0': 0.6996148984503365,
#   '1': 0.8555235679456379,
#   '2': 0.557613127438477,
#   '3': 0.7457103726224552,
#   '4': 0.4132492406485047},
#  'temp7': {'0': 0.4263691690025617,
#   '1': 0.3640531398300667,
# ...

# %%
corr = correlation_df.corr(method="pearson")

# %%
corr.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style  type="text/css" >
#     #T_93483462_6d69_11ec_95af_0242ac110003row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_93483462_6d69_11ec_95af_0242ac110003row0_col1 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_93483462_6d69_11ec_95af_0242ac110003row0_col2 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_93483462_6d69_11ec_95af_0242ac110003row0_col3 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_93483462_6d69_11ec_95af_0242ac110003row0_col4 {
#             background-color:  #f3c8b2;
#             color:  #000000;
#         }    #T_93483462_6d69_11ec_95af_0242ac110003row0_col5 {
#             background-color:  #f2cab5;
#             color:  #000000;
#         }    #T_93483462_6d69_11ec_95af_0242ac110003row0_col6 {
#             background-color:  #a6c4fe;
#             color:  #000000;
# ...
