# %%
import json
import ast
import pandas as pd

a_file = open("1_seat_CLS_embeddings.json", "r")
seat_CLS_templates = a_file.read()
seat_CLS_templates = json.loads(seat_CLS_templates)
cls_correlation_df = pd.DataFrame(seat_CLS_templates)
cls_df = cls_correlation_df.mean(axis = 1)
cls_df
# Out:
# 0     0.947709
# 1     0.799808
# 2     1.033719
# 3     0.848186
# 4     1.150456
# 5     0.866613
# 6     0.757134
# 7     0.924970
# 8     0.813987
# 9     0.906943
# 10    0.735473
# 11    0.936911
# 12    0.982089
# 13    0.750267
# 14    1.039305
# 15    0.904302
# 16    0.793564
# 17    0.764184
# 18    0.926804
# 19    0.939457
# dtype: float64

# %%
import json
import ast
import pandas as pd

a_file = open("2_seat_no_context_cls_embeddings.json", "r")
seat_no_context_templates_Language_models = a_file.read()
seat_no_context_templates_Language_models = json.loads(seat_no_context_templates_Language_models)
seat_no_context_templates_Language_models_df = pd.DataFrame(seat_no_context_templates_Language_models)
seat_no_context_templates_Language_models_df = seat_no_context_templates_Language_models_df.mean(axis = 1)
seat_no_context_templates_Language_models_df
# Out:
# 0     0.855382
# 1     0.942012
# 2     0.789841
# 3     0.379351
# 4     1.073988
# 5    -0.107562
# 6     0.434602
# 7     0.836531
# 8     0.711487
# 9     0.835985
# 10    0.492031
# 11    0.941073
# 12    0.587726
# 13    0.766124
# 14    0.434297
# 15    1.100616
# 16   -0.162728
# 17    0.878521
# 18    0.994258
# 19    0.775102
# dtype: float64

# %%
import json
import ast
import pandas as pd

a_file = open("3_seat_no_context_pooled_embeddings.json", "r")
seat_no_context_pooled_templates_Language_models = a_file.read()
seat_no_context_pooled_templates_Language_models = json.loads(seat_no_context_pooled_templates_Language_models)
seat_no_context_pooled_templates_Language_models_df = pd.DataFrame(seat_no_context_pooled_templates_Language_models)
seat_no_context_pooled_templates_Language_models_df = seat_no_context_pooled_templates_Language_models_df.mean(axis = 1)
seat_no_context_pooled_templates_Language_models_df
# Out:
# 0     0.933331
# 1     0.717216
# 2     1.268379
# 3     0.512444
# 4     1.313940
# 5     0.357214
# 6     0.561217
# 7     1.143939
# 8     0.522984
# 9     0.821094
# 10    0.641716
# 11    0.863910
# 12    0.904282
# 13    0.833185
# 14    0.585761
# 15    0.667184
# 16    0.248367
# 17    0.753351
# 18    0.858966
# 19    0.467484
# dtype: float64

# %%
import json
import ast
import pandas as pd

a_file = open("4_seat_SWP_pooled_embeddings.json", "r")
Seat_SWP_pooled_Language_models = a_file.read()
Seat_SWP_pooled_Language_models = json.loads(Seat_SWP_pooled_Language_models)
Seat_SWP_pooled_Language_models_df = pd.DataFrame(Seat_SWP_pooled_Language_models)
Seat_SWP_pooled_Language_models_df = Seat_SWP_pooled_Language_models_df.mean(axis = 1)
Seat_SWP_pooled_Language_models_df
# Out:
# 0     0.830338
# 1     0.857556
# 2     1.174614
# 3     0.669389
# 4     1.159176
# 5     0.896032
# 6     0.676717
# 7     0.980488
# 8     0.806248
# 9     0.970033
# 10    0.822078
# 11    0.913942
# 12    0.891853
# 13    0.850181
# 14    0.855262
# 15    0.727541
# 16    0.831455
# 17    0.873298
# 18    0.831495
# 19    0.577577
# dtype: float64

# %%
import json
import ast
import pandas as pd

a_file = open("5_seat_SWP_first_embeddings.json", "r")
seat_SWP_templates_Language_models = a_file.read()
seat_SWP_templates_Language_models = json.loads(seat_SWP_templates_Language_models)
seat_SWP_templates_Language_models_df = pd.DataFrame(seat_SWP_templates_Language_models)
seat_SWP_templates_Language_models_df = seat_SWP_templates_Language_models_df.mean(axis = 1)
seat_SWP_templates_Language_models_df
# Out:
# 0     0.663465
# 1     0.665840
# 2     1.111355
# 3     0.413279
# 4     1.041005
# 5     0.560347
# 6     0.461250
# 7     0.756153
# 8     0.535995
# 9     0.952501
# 10    0.693230
# 11    0.874235
# 12    0.745648
# 13    0.711062
# 14    0.612568
# 15    0.471917
# 16    0.771092
# 17    0.665918
# 18    0.511300
# 19    0.434494
# dtype: float64

# %%
import json
import ast
import pandas as pd

a_file = open("6_seat_vulic_templates_Language_models.json", "r")
seat_vulic_templates_Language_models = a_file.read()
seat_vulic_templates_Language_models = json.loads(seat_vulic_templates_Language_models)
seat_vulic_templates_Language_models_df = pd.DataFrame(seat_vulic_templates_Language_models)
seat_vulic_templates_Language_models_df = seat_vulic_templates_Language_models_df.mean(axis = 1)
seat_vulic_templates_Language_models_df
# Out:
# 0     0.871221
# 1     1.058285
# 2     1.313952
# 3     0.815520
# 4     1.322140
# 5     0.945198
# 6     0.910547
# 7     1.438235
# 8     0.907746
# 9     1.173698
# 10    0.885126
# 11    1.202888
# 12    0.990269
# 13    1.161330
# 14    1.209916
# 15    0.755755
# 16    0.792208
# 17    1.089084
# 18    0.889420
# 19    0.819824
# dtype: float64

# %%
corr_df = pd.concat([cls_df, seat_no_context_templates_Language_models_df, seat_no_context_pooled_templates_Language_models_df, Seat_SWP_pooled_Language_models_df, seat_SWP_templates_Language_models_df, seat_vulic_templates_Language_models_df], axis=1)
corr_df
# Out:
#            0         1         2         3         4         5
# 0   0.947709  0.855382  0.933331  0.830338  0.663465  0.871221
# 1   0.799808  0.942012  0.717216  0.857556  0.665840  1.058285
# 2   1.033719  0.789841  1.268379  1.174614  1.111355  1.313952
# 3   0.848186  0.379351  0.512444  0.669389  0.413279  0.815520
# 4   1.150456  1.073988  1.313940  1.159176  1.041005  1.322140
# 5   0.866613 -0.107562  0.357214  0.896032  0.560347  0.945198
# 6   0.757134  0.434602  0.561217  0.676717  0.461250  0.910547
# 7   0.924970  0.836531  1.143939  0.980488  0.756153  1.438235
# 8   0.813987  0.711487  0.522984  0.806248  0.535995  0.907746
# 9   0.906943  0.835985  0.821094  0.970033  0.952501  1.173698
# 10  0.735473  0.492031  0.641716  0.822078  0.693230  0.885126
# 11  0.936911  0.941073  0.863910  0.913942  0.874235  1.202888
# 12  0.982089  0.587726  0.904282  0.891853  0.745648  0.990269
# 13  0.750267  0.766124  0.833185  0.850181  0.711062  1.161330
# 14  1.039305  0.434297  0.585761  0.855262  0.612568  1.209916
# 15  0.904302  1.100616  0.667184  0.727541  0.471917  0.755755
# 16  0.793564 -0.162728  0.248367  0.831455  0.771092  0.792208
# 17  0.764184  0.878521  0.753351  0.873298  0.665918  1.089084
# 18  0.926804  0.994258  0.858966  0.831495  0.511300  0.889420
# 19  0.939457  0.775102  0.467484  0.577577  0.434494  0.819824

# %%
corr = corr_df.corr(method="pearson")

# %%
corr.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style  type="text/css" >
#     #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow0_col1 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow0_col2 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow0_col3 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow0_col4 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow0_col5 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow1_col0 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow1_col2 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow1_col3 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow1_col5 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow2_col0 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow2_col1 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow2_col3 {
#             background-color:  #f7b497;
#             color:  #000000;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow2_col4 {
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow2_col5 {
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow3_col0 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow3_col1 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow3_col2 {
#             background-color:  #f7b497;
#             color:  #000000;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow3_col4 {
#             background-color:  #dc5d4a;
#             color:  #000000;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow3_col5 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow4_col0 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow4_col2 {
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow4_col3 {
#             background-color:  #dc5d4a;
#             color:  #000000;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow4_col5 {
#             background-color:  #f6bea4;
#             color:  #000000;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow5_col0 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow5_col1 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow5_col2 {
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow5_col3 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow5_col4 {
#             background-color:  #f6bea4;
#             color:  #000000;
#         }    #T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_2d0f1af6_5c59_11ec_adbf_0242ac11000a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>        <th class="col_heading level0 col5" >5</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2d0f1af6_5c59_11ec_adbf_0242ac11000alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow0_col1" class="data row0 col1" >0.323747</td>
#                         <td id="T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow0_col2" class="data row0 col2" >0.587241</td>
#                         <td id="T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow0_col3" class="data row0 col3" >0.526155</td>
#                         <td id="T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow0_col4" class="data row0 col4" >0.453087</td>
#                         <td id="T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow0_col5" class="data row0 col5" >0.449602</td>
#             </tr>
#             <tr>
#                         <th id="T_2d0f1af6_5c59_11ec_adbf_0242ac11000alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow1_col0" class="data row1 col0" >0.323747</td>
#                         <td id="T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow1_col2" class="data row1 col2" >0.683285</td>
#                         <td id="T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow1_col3" class="data row1 col3" >0.218835</td>
#                         <td id="T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow1_col4" class="data row1 col4" >0.213977</td>
#                         <td id="T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow1_col5" class="data row1 col5" >0.335509</td>
#             </tr>
#             <tr>
#                         <th id="T_2d0f1af6_5c59_11ec_adbf_0242ac11000alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow2_col0" class="data row2 col0" >0.587241</td>
#                         <td id="T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow2_col1" class="data row2 col1" >0.683285</td>
#                         <td id="T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow2_col3" class="data row2 col3" >0.746619</td>
#                         <td id="T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow2_col4" class="data row2 col4" >0.686136</td>
#                         <td id="T_2d0f1af6_5c59_11ec_adbf_0242ac11000arow2_col5" class="data row2 col5" >0.730278</td>
#             </tr>
#             <tr>
#                         <th id="T_2d0f1af6_5c59_11ec_adbf_0242ac11000alevel0_row3" class="row_heading le
